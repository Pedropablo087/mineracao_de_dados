# %%
import pandas as pd

# %% [markdown]
# Leitura do dataset e vira dataframe

# %%
df = pd.read_csv('iris.csv.xls')

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\LoraxCrazy\Documents\ESTUDO\Mineraçao de dsdos\cod_estudo

# %% [markdown]
# Exibindo algumas informações: como detalhes iniciais

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
type(df['Name'])
# Out:
# pandas.Series

# %% [markdown]
# vizualizar as primeiras linhas do data frame(padrão 5 linhas)

# %%
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# vizualizar as 10 primeiras linhsa do data frame

# %%
df.head(10)
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa
# 5          5.4         3.9          1.7         0.4  Iris-setosa
# 6          4.6         3.4          1.4         0.3  Iris-setosa
# 7          5.0         3.4          1.5         0.2  Iris-setosa
# 8          4.4         2.9          1.4         0.2  Iris-setosa
# 9          4.9         3.1          1.5         0.1  Iris-setosa

# %% [markdown]
# vizualiza todos do df

# %%
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# retorna (n_linhas, n_colunas).

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# mostra as informações

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  150 non-null    float64
#  1   SepalWidth   150 non-null    float64
#  2   PetalLength  150 non-null    float64
#  3   PetalWidth   150 non-null    float64
#  4   Name         150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 6.0 KB

# %% [markdown]
# mostra as ultimas 5 linhas

# %%
df.tail()
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica

# %% [markdown]
# retorna uma linha aleatória do DataFrame.

# %%
df.sample()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 3          4.6         3.1          1.5         0.2  Iris-setosa

# %% [markdown]
# retorna 10 linhas aleatórias

# %%
df.sample(10)
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth             Name
# 47           4.6         3.2          1.4         0.2      Iris-setosa
# 29           4.7         3.2          1.6         0.2      Iris-setosa
# 5            5.4         3.9          1.7         0.4      Iris-setosa
# 67           5.8         2.7          4.1         1.0  Iris-versicolor
# 68           6.2         2.2          4.5         1.5  Iris-versicolor
# 39           5.1         3.4          1.5         0.2      Iris-setosa
# 24           4.8         3.4          1.9         0.2      Iris-setosa
# 121          5.6         2.8          4.9         2.0   Iris-virginica
# 41           4.5         2.3          1.3         0.3      Iris-setosa
# 4            5.0         3.6          1.4         0.2      Iris-setosa

# %% [markdown]
# Exibição de uma Feature, também chamado de característica. Esta se chama "Name" e a outra "SepalLength"

# %%
df['Name']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Name, Length: 150, dtype: str

# %%
df['SepalLength']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLength, Length: 150, dtype: float64

# %% [markdown]
# conhecendo as colunas

# %%
df.columns
# Out:
# Index(['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Name'], dtype='str')

# %% [markdown]
# pré-seleção de elementos

# %%
acimaDe3 = df['PetalLength'] > 3.0

# %%
acimaDe3
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: PetalLength, Length: 150, dtype: bool

# %%
acimaDe3.head(10)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: PetalLength, dtype: bool

# %%
armazenarInfos = df[10:20]

# %%
armazenarInfos
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 10          5.4         3.7          1.5         0.2  Iris-setosa
# 11          4.8         3.4          1.6         0.2  Iris-setosa
# 12          4.8         3.0          1.4         0.1  Iris-setosa
# 13          4.3         3.0          1.1         0.1  Iris-setosa
# 14          5.8         4.0          1.2         0.2  Iris-setosa
# 15          5.7         4.4          1.5         0.4  Iris-setosa
# 16          5.4         3.9          1.3         0.4  Iris-setosa
# 17          5.1         3.5          1.4         0.3  Iris-setosa
# 18          5.7         3.8          1.7         0.3  Iris-setosa
# 19          5.1         3.8          1.5         0.3  Iris-setosa

# %% [markdown]
# faz um recorte de colunas específicas do DataFrame.

# %%
corteEspecifico = df[['SepalLength','Name']]

# %%
corteEspecifico.head()
# Out:
#    SepalLength         Name
# 0          5.1  Iris-setosa
# 1          4.9  Iris-setosa
# 2          4.7  Iris-setosa
# 3          4.6  Iris-setosa
# 4          5.0  Iris-setosa

# %% [markdown]
# mostra um resumor estrutural do dataframe

# %%
corteEspecifico.info
# Out:
# <bound method DataFrame.info of      SepalLength            Name
# 0            5.1     Iris-setosa
# 1            4.9     Iris-setosa
# 2            4.7     Iris-setosa
# 3            4.6     Iris-setosa
# 4            5.0     Iris-setosa
# ..           ...             ...
# 145          6.7  Iris-virginica
# 146          6.3  Iris-virginica
# 147          6.5  Iris-virginica
# 148          6.2  Iris-virginica
# 149          5.9  Iris-virginica
#
# [150 rows x 2 columns]>

# %% [markdown]
# serve para contar quantas vezes cada valor aparece na coluna Name

# %%
df['Name'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Name, Length: 150, dtype: str>

# %% [markdown]
# série contendo a contagem de valores únicos na coluna 'Nome'

# %%
df['Name'].value_counts()
# Out:
# Name
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# somou todos os valores da coluna PetalLength

# %%
somaComprimentoPetalas = df['PetalLength'].sum()

# %%
somaComprimentoPetalas
# Out:
# np.float64(563.8)

# %% [markdown]
# conta quantos valores True existem na variável acimaDe3.

# %%
soma_acimade3 = acimaDe3.sum()

# %%
soma_acimade3
# Out:
# np.int64(99)

# %% [markdown]
# Exibindo a soma total de todas as features do dataframe iris

# %%
df.sum()
# Out:
# SepalLength                                                876.5
# SepalWidth                                                 458.1
# PetalLength                                                563.8
# PetalWidth                                                 179.8
# Name           Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# dtype: object

# %% [markdown]
# Exibindo o valor máximo de todas as features do dataframe iris

# %%
df.max()
# Out:
# SepalLength               7.9
# SepalWidth                4.4
# PetalLength               6.9
# PetalWidth                2.5
# Name           Iris-virginica
# dtype: object

# %% [markdown]
# Exibindo o valor mínimo de todas as features do dataframe iris

# %%
df.min()
# Out:
# SepalLength            4.3
# SepalWidth             2.0
# PetalLength            1.0
# PetalWidth             0.1
# Name           Iris-setosa
# dtype: object

# %% [markdown]
# Calculando a média para o dataframe todo

# %%
mediaPetalaComprimento=df['PetalLength'].mean()

# %% [markdown]
# Calculando a média para apenas a variável armazenarInfos

# %%
armazenarInfos['PetalLength'].mean()
# Out:
# np.float64(1.42)

# %% [markdown]
# Calculando a mediana para o dataframe todo

# %%
medianaPetalaComprimento=df['PetalLength'].median()

# %% [markdown]
# Print de todas as estatísticas relevantes deste dataframe, note que inicialmente eu pedi média e mediana através de uma variável. Nas últimas três eu só joguei o comando direto no print (valor máximo, valor mínimo, somatório total)

# %%
print("Media do Comprimento de Pétala: ", mediaPetalaComprimento, "\nMediana do Comprimento de Pétala: ", medianaPetalaComprimento, "\nValor Máximo do Comprimento de Pétala: ", df['PetalLength'].max(), "\nValor Mínimo do Comprimento de Pétala: ", df['PetalLength'].min(), "\nSomatório do Comprimento de Pétala: ", df['PetalLength'].sum())
# Out:
# Media do Comprimento de Pétala:  3.758666666666666
# Mediana do Comprimento de Pétala:  4.35
# Valor Máximo do Comprimento de Pétala:  6.9
# Valor Mínimo do Comprimento de Pétala:  1.0
# Somatório do Comprimento de Pétala:  563.8

# %% [markdown]
# Plot em gráfico de barra, em gráfico de pizza, gráfico de pizza melhorado

# %%
df['Name'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Name'>

# %%
df['Name'].value_counts().plot(kind='pie')
# Out:
# <Axes: >

# %%
df['Name'].value_counts().plot(kind='pie', autopct='%1.1f%%', title='Distribuição das Espécies da flor Íris')
# Out:
# <Axes: title={'center': 'Distribuição das Espécies da flor Íris'}>
